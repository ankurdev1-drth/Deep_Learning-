# %% [markdown]
# # Question 8:

# %% [markdown]
# Practising training a DNN on CIFAR10 image dataset

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torchmetrics
import torch
import torchvision
import torch.optim as optim # for optimizing it 
from torch.utils.data import DataLoader # for loading data
from torchvision import transforms # for image transformation

# %% [markdown]
# CIFAR10 Dataset Info:
# - 60,000 , 32 X 32 pixel color images(50,000 for training and 10,000 for testing) with 10 classes

# %%
from torchvision.datasets import CIFAR10

# %%
train_set = CIFAR10(
    root = "./data",  #root gives the location where the dataset is to be downloaded 
    train = True,
    download = True
)
# Out:
#  17%|████████████████████████▋                                                                                                                         | 28.9M/170M [22:22<36:00, 65.6kB/s]
